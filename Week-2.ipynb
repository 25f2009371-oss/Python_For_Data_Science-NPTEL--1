# %%
strSample ='learning'
print(strSample)
# Out:
# learning

# %%
lstNumbers=[1,2,3,4,5,3,5,3,2]
print(lstNumbers)
# Out:
# [1, 2, 3, 4, 5, 3, 5, 3, 2]

# %%
lstSample=[1,2,'s','sam',2]
print(lstSample)
# Out:
# [1, 2, 's', 'sam', 2]

# %%
from array import *

arrSample=array('i',[1,2,3,4])
#here i represent integer
print(arrSample)

for x in arrSample: print(x)
# Out:
# array('i', [1, 2, 3, 4])
# 1
# 2
# 3
# 4

# %%
from array import *

# %%
arrFloat=array('f',[1,2,3,4])
#here f represent integer

for x in arrFloat:print(x)
# Out:
# 1.0
# 2.0
# 3.0
# 4.0

# %%
from array import *

arrString = array('u',['a','b','c','d'])

for x in arrString: 
    print(x)
# Out:
# a
# b
# c
# d
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8104\462339833.py:3: DeprecationWarning: The 'u' type code is deprecated and will be removed in Python 3.16
#   arrString = array('u',['a','b','c','d'])

# %%
tu=(1,2,3,45,6,'py') #tuple

tuple_s=1,2,'sample' #tuple packing

print(tuple_s)
print(type(tuple_s))
# Out:
# (1, 2, 'sample')
# <class 'tuple'>

# %%
dict1={'first':1,'second':2, 'three':3}

# %%
dic_lst=dict([('first',1),('second',2),('third',3)])

# %%
dic_lst
# Out:
# {'first': 1, 'second': 2, 'third': 3}

# %%
setSample={'example',24,87.5,24,'date'}
setSample
# Out:
# {24, 87.5, 'date', 'example'}

# %%
print(set('ayush'))
print(set('example'))
# Out:
# {'h', 'u', 's', 'a', 'y'}
# {'p', 'x', 'a', 'e', 'm', 'l'}

# %%
rangesample=range(1,12,4)

for i in rangesample:
    print(i)
# Out:
# 1
# 5
# 9
