# %%
strsample="Learning"

# %%
strsample[slice(0,5,2)]
# Out:
# 'Lan'

# %%
strsample[:3]
# Out:
# 'Lea'

# %%
strsample[2:]
# Out:
# 'arning'

# %%
lstSample=[1,2,'a','sam',2]

# %%
lstSample[:3]
# Out:
# [1, 2, 'a']

# %%
from array import *
arr=array('i',[1,2,3,4])

# %%
arr
# Out:
# array('i', [1, 2, 3, 4])

# %%
arr[1:-1]
# Out:
# array('i', [2, 3])

# %%
print(strsample+' '+'python')
print(strsample)
# Out:
# Learning python
# Learning

# %%
newString = strsample+ ' '+'python'

# %%
newString
# Out:
# 'Learning python'

# %%
print(lstSample+['py'])
# Out:
# [1, 2, 'a', 'sam', 2, 'py']

# %%
arr
# Out:
# array('i', [1, 2, 3, 4])

# %%
print(arr+[50,60])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(arr+[50,60])
#
# TypeError: can only append array (not "list") to array

# %%
print(arr+array('i',[50,60]))
# Out:
# array('i', [1, 2, 3, 4, 50, 60])

# %%
tupSample=(1,2,3,4,3,'py','th','on')

# %%
tupSample+(1,23)
# Out:
# (1, 2, 3, 4, 3, 'py', 'th', 'on', 1, 23)

# %%
setsample={24,'data','example',87.5}

# %%
setsample=setsample,24

# %%
setsample
# Out:
# ({24, 87.5, 'data', 'example'}, 24)

# %%
(strsample+' ')*3
# Out:
# 'Learning Learning Learning '

# %%
lstSample*3
# Out:
# [1, 2, 'a', 'sam', 2, 1, 2, 'a', 'sam', 2, 1, 2, 'a', 'sam', 2]

# %%
lstSample[0]*2
# Out:
# 2

# %%
lstSample[:]*=2

# %%
lstSample
# Out:
# [1,
#  2,
#  'a',
#  'sam',
#  2,
#  1,
#  2,
#  'a',
#  'sam',
#  2,
#  1,
#  2,
#  'a',
#  'sam',
#  2,
#  1,
#  2,
#  'a',
#  'sam',
#  2]

# %%
tupSample[0:4]*2
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)
