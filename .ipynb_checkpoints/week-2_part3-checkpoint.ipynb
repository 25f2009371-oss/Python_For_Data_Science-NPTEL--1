# %%
set("land based tank is dangerous to use")
# Out:
# {' ', 'a', 'b', 'd', 'e', 'g', 'i', 'k', 'l', 'n', 'o', 'r', 's', 't', 'u'}

# %%
lst_sam=[1,2,'a','sam',2]

# %%
lst_sam.index('sam')
# Out:
# 3

# %%
tp=(2,3,4,24)

# %%
tp[2:]*2
# Out:
# (4, 24, 4, 24)

# %%
for i in tp:
    print(i*2)
# Out:
# 4
# 6
# 8
# 48

# %%
rangesample=range(0,12,3)

# %%
len(rangesample)
# Out:
# 4

# %%
rangesample.index(9)
# Out:
# 3

# %%
len("ayush")
# Out:
# 5

# %%
dict_list=dict([(1,2),(2,4),(3,6),(4,9),(5,10)])

# %%
dict_list
# Out:
# {1: 2, 2: 4, 3: 6, 4: 9, 5: 10}

# %%
t=(1,2.0,4)

# %%
strSample="learning is fun!"
print(strSample)
# Out:
# learning is fun!

# %%
strSample.capitalize()
# Out:
# 'Learning is fun!'

# %%
strSample.title()
# Out:
# 'Learning Is Fun!'

# %%
strSample.upper()
# Out:
# 'LEARNING IS FUN!'

# %%
strSample.lower()
# Out:
# 'learning is fun!'

# %%
strSample.replace("fun","important")
# Out:
# 'learning is important!'

# %%
st=strSample.casefold()
st
# Out:
# 'learning is fun!'

# %%
st.count('James, while John had had had, had had had had; that had had a better effect on the teacher')

# %%
a="James, while John had had had, had had had had; that had had a better effect on the teacher"

# %%
strSample.isalnum()
# Out:
# False

# %%
name1="Gitaa"
name2="PVT"
name3="Ltd"

# %%
name='{} {} {}'.format(name1,name2,name3)

# %%
name
# Out:
# 'Gitaa PVT Ltd'

# %%
print(help(str))
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Lenovo\\OneDrive\\Desktop\\Python for data Science\\Python_For_Data_Science-NPTEL--1'

# %%
import pandas as pd

# %%
df=pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
`
